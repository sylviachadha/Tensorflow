# %% [markdown]
# # Executing tf program on Google Colab (cloud based platform)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Google colab will open an environment of jupyter notebook for you to code and the code will be executed on google servers. (computation and memory of google servers will be used).

# %% [markdown]
# ## Google Colab vs Jupyter Notebook

# %% [markdown]
# Google Colab (Remote)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Jupyter Notebooks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Python, R and Jupyter Notebook through Anaconda

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CPU and RAM

# %% [markdown]
# ![image.png](attachment:image.png)
